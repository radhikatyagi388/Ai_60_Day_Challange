# %% [markdown]
# <a href="https://colab.research.google.com/github/radhikatyagi388/Ai_60_day_challange/blob/main/Day_4_Sentence_Embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
model=SentenceTransformer('all-MiniLM-L6-v2')
sentences=[
    "I love dogs.",
    "Dogs are my favorite animal.",
    "I enjoy playing with puppies.",
    "The weather is very hot today.",
    "Python is popular programming language."
]
print(sentences)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
embeddings=model.encode(sentences)
print(embeddings)
# Out:
# [[-0.00410113 -0.01932426  0.11508981 ...  0.09527826  0.03065364
#   -0.01889581]
#  [-0.03480056 -0.02871619  0.10813224 ...  0.09316239  0.02967603
#    0.01136484]
#  [-0.03315932 -0.06140278  0.08605665 ...  0.11555309  0.03744073
#    0.06231909]
#  [ 0.00416245  0.07910341  0.09407218 ... -0.00453473 -0.14473099
#    0.08650693]
#  [-0.04110067 -0.01438371 -0.01252307 ...  0.12594524  0.16360795
#    0.02830915]]

# %%
print("embedding shape:",embeddings.shape)
# Out:
# embedding shape: (5, 384)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity([embeddings[0]],[embeddings[1]])
print("similarity:",similarity)
# Out:
# similarity: [[0.81134355]]

# %%
for i in range(len(sentences)):
  for j in range(i+1,len(sentences)):
    score=cosine_similarity(
        [embeddings[i]],
        [embeddings[j]]
        )[0][0]
  print(f"sentence{i+1}vs sentence{j+1}:{score:.4f}")
# Out:
# sentence1vs sentence5:0.1460
# sentence2vs sentence5:0.1649
# sentence3vs sentence5:0.1959
# sentence4vs sentence5:0.0561
# sentence5vs sentence5:0.0561

# %%
best_score = -1
best_pair = None

for i in range(len(sentences)):
    for j in range(i + 1, len(sentences)):
        score = cosine_similarity(
            [embeddings[i]],
            [embeddings[j]]
        )[0][0]

        if score > best_score:
            best_score = score
            best_pair = (sentences[i], sentences[j])

print("Most similar sentences:")
print(best_pair[0])
print(best_pair[1])
print(f"Similarity score: {best_score:.4f}")
# Out:
# Most similar sentences:
# I love dogs.
# Dogs are my favorite animal.
# Similarity score: 0.8113

# %%
#### Reflection

##Today I learned how sentence embeddings convert text into numerical vectors that capture semantic meaning. I compared several sentences using cosine similarity and observed that sentences with related meanings generally received higher similarity scores, even when they did not contain exactly the same words.

##What surprised me was that the model can recognize relationships between sentences based on their meaning rather than simply matching individual words. This helped me understand why embeddings are important for modern AI applications such as semantic search, recommendation systems, and RAG.
